# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt, style
style.use('ggplot')
style.use('fivethirtyeight') 
style.use('seaborn-v0_8-notebook')

# %%
x = np.arange(0, 100, 1)

# %%
y = 1/(x- 24)
# Out:
# /var/folders/8g/g2n329bx4n79cpb69z44n1fh0000gp/T/ipykernel_14321/1888303772.py:1: RuntimeWarning: divide by zero encountered in divide
#   y = 1/(x- 24)

# %%
plt.plot(x, y)
